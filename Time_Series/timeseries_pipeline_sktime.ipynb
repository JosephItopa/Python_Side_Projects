# %% [markdown]
# <a href="https://colab.research.google.com/github/light-ti-man/Drop_of_my_Python_Projects/blob/master/Time_Series/timeseries_pipeline_sktime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sktime
# Out:
# Collecting sktime
#   Downloading https://files.pythonhosted.org/packages/34/f8/c4d9c83406245dc13aeb248bd9a8df1b35fd76dd815672d5090259c83dcc/sktime-0.4.1-cp36-cp36m-manylinux2014_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 2.6MB/s
# Requirement already satisfied: wheel in /usr/local/lib/python3.6/dist-packages (from sktime) (0.34.2)
# Collecting scikit-learn>=0.23.0
#   Downloading https://files.pythonhosted.org/packages/d9/3a/eb8d7bbe28f4787d140bb9df685b7d5bf6115c0e2a969def4027144e98b6/scikit_learn-0.23.1-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
#      |████████████████████████████████| 6.9MB 34.9MB/s
# Collecting statsmodels>=0.11.0
#   Downloading https://files.pythonhosted.org/packages/cb/83/540fd83238a18abe6c2d280fa8e489ac5fcefa1f370f0ca1acd16ae1b860/statsmodels-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (8.7MB)
#      |████████████████████████████████| 8.7MB 49.1MB/s
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.6/dist-packages (from sktime) (1.18.5)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from sktime) (1.0.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.23.0->sktime) (0.16.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.23.0->sktime) (1.4.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.11.0->sktime) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=1.0.0->sktime) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=1.0.0->sktime) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->statsmodels>=0.11.0->sktime) (1.15.0)
# Installing collected packages: threadpoolctl, scikit-learn, statsmodels, sktime
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed scikit-learn-0.23.1 sktime-0.4.1 statsmodels-0.11.1 threadpoolctl-2.1.0

# %%
import numpy as np
from sktime.datasets import load_airline
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting.forecasting import plot_ys

# %%
y = load_airline()
y_train, y_test = temporal_train_test_split(y)
plot_ys(y_train, y_test, labels=["y_train", "y_test"])
fh = np.arange(len(y_test)) + 1

# %%
from sktime.forecasting.compose import ReducedRegressionForecaster
from sklearn.ensemble import RandomForestRegressor
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import smape_loss

# %%
regressor = RandomForestRegressor()
forecaster = ReducedRegressionForecaster(regressor, window_length=12)
forecaster.fit(y_train)
fh = np.arange(len(y_test)) + 1
y_pred = forecaster.predict(fh)

plot_ys(y_train, y_test, y_pred, labels=['y_train', 'y_test', 'y_pred'])
smape_loss(y_test, y_pred)
# Out:
# 0.12901861973128728

# %%
naive_forecaster_seasonal = NaiveForecaster(strategy="seasonal_last", sp=12)
naive_forecaster_seasonal.fit(y_train)
y_seasonal_last = naive_forecaster_seasonal.predict(fh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-079b41124e98> in <module>()
#       1 naive_forecaster_seasonal = NaiveForecaster(strategy="seasonal_last", sp=12)
#       2 naive_forecaster_seasonal.fit(y_train)
# ----> 3 y_seasonal_last = naive_forecaster_seasonal.predict(fh)
#
# NameError: name 'fh' is not defined

# %%
plot_ys(y_train, y_test, y_last, y_seasonal_last, labels=["y_train", "y_test", "y_pred_last", "y_pred_seasonal_last"]);
smape_loss(y_last, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a109d30575a5> in <module>()
# ----> 1 plot_ys(y_train, y_test, y_last, y_seasonal_last, labels=["y_train", "y_test", "y_pred_last", "y_pred_seasonal_last"]);
#       2 smape_loss(y_last, y_test)
#
# NameError: name 'y_last' is not defined
